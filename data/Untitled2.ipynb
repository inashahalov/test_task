# %%
df = pd.read_csv('raw_2020.csv', sep=';')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('raw_2020.csv', sep=';')
#       2 print(df.head())
#
# NameError: name 'pd' is not defined
