# %%
import pandas as pd

# Читаем с правильным разделителем
df = pd.read_csv('raw_2020.csv', sep=';')

print("=" * 50)
print("1. ПЕРВЫЕ 5 СТРОК:")
print("=" * 50)
print(df.head())

print("\n" + "=" * 50)
print("2. СПИСОК КОЛОНОК:")
print("=" * 50)
print(df.columns.tolist())

print("\n" + "=" * 50)
print("3. РАЗМЕРЫ:")
print("=" * 50)
print(f"Строк: {df.shape[0]}, Колонок: {df.shape[1]}")

print("\n" + "=" * 50)
print("4. ПРОВЕРКА СТОЛБЦОВ:")
print("=" * 50)
print(f"Deaths: {'✅ Есть' if 'Deaths' in df.columns else '❌ Нет'}")
print(f"Confirmed: {'✅ Есть' if 'Confirmed' in df.columns else '❌ Нет'}")

print("\n" + "=" * 50)
print("5. ТИПЫ ДАННЫХ:")
print("=" * 50)
print(df.dtypes)
# Out:
# ...
# 1. ПЕРВЫЕ 5 СТРОК:
# ...
#   Country/Region Province/State 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0    Afghanistan            NaN       0        0        0        0        0
# 1        Albania            NaN       0        0        0        0        0
# 2        Algeria            NaN       0        0        0        0        0
# 3        Andorra            NaN       0        0        0        0        0
# 4         Angola            NaN       0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  12/23/20  12/24/20  12/25/20  12/26/20  \
# 0        0        0        0  ...      2105      2126      2135      2148
# 1        0        0        0  ...      1117      1125      1134      1143
# 2        0        0        0  ...      2696      2705      2716      2722
# 3        0        0        0  ...        82        83        83        83
# 4        0        0        0  ...       393       393       396       399
#
# ...
